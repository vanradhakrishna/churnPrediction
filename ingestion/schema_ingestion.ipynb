# %%
df = spark.read.csv("s3://my-databricks-ml-bucket-2026/Churn_Modelling.csv", header=True, inferSchema=True)
df.write.mode("overwrite").saveAsTable("ml_catalog.bronze.churn_raw")
spark.table("ml_catalog.bronze.churn_raw").display()
