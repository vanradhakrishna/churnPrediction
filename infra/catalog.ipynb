-- %%
#commit trigger
-- Catalog
CREATE CATALOG IF NOT EXISTS ml_catalog
MANAGED LOCATION 's3://my-databricks-ml-bucket-2026/';

-- Schemas
CREATE SCHEMA IF NOT EXISTS ml_catalog.bronze;
CREATE SCHEMA IF NOT EXISTS ml_catalog.silver;
CREATE SCHEMA IF NOT EXISTS ml_catalog.gold;
CREATE SCHEMA IF NOT EXISTS ml_catalog.ml;

-- %%
-- Volume (VERY IMPORTANT)
CREATE VOLUME IF NOT EXISTS ml_catalog.ml.volume_models;

-- %%
SHOW SCHEMAS IN ml_catalog;
